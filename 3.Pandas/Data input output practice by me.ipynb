# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Test1.csv')

# %%
df
# Out:
#    ID      Name  Number Section
# 0   1     Babul      30       A
# 1   2     kobir      50       B
# 2   3  kolu mia      15       A
# 3   4     Based      12       A
# 4   5   Mukhles      56       C
# 5   6     kader      60       C
# 6   7     Abbas      45       A
# 7   8    Jabbar      50       B
# 8   9     Rafiq      78       B
# 9  10     Kasem       9       D

# %%
pd.read_excel('Test1.xlsx')
# Out:
#    ID      Name  Number Section
# 0   1     Babul      30       A
# 1   2     kobir      50       B
# 2   3  kolu mia      15       A
# 3   4     Based      12       A
# 4   5   Mukhles      56       C
# 5   6     kader      60       C
# 6   7     Abbas      45       A
# 7   8    Jabbar      50       B
# 8   9     Rafiq      78       B
# 9  10     Kasem       9       D

# %%
data=pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
data[0].head()
# Out:
#                 Bank NameBank           CityCity StateSt  CertCert  \
# 0              Signature Bank           New York      NY     57053
# 1         Silicon Valley Bank        Santa Clara      CA     24735
# 2           Almena State Bank             Almena      KS     15426
# 3  First City Bank of Florida  Fort Walton Beach      FL     16748
# 4        The First State Bank      Barboursville      WV     14361
#
#                           Acquiring InstitutionAI Closing DateClosing  \
# 0                     Signature Bridge Bank, N.A.      March 12, 2023
# 1  Deposit Insurance National Bank of Santa Clara      March 10, 2023
# 2                                     Equity Bank    October 23, 2020
# 3                       United Fidelity Bank, fsb    October 16, 2020
# 4                                  MVB Bank, Inc.       April 3, 2020
#
#    FundFund
# 0     10540
# 1     10539
# 2     10538
# 3     10537
# 4     10536

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///:memory:')

# %%
df.to_sql('my_table',engine)
# Out:
# 10

# %%
sqldf=pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#    index  ID      Name  Number Section
# 0      0   1     Babul      30       A
# 1      1   2     kobir      50       B
# 2      2   3  kolu mia      15       A
# 3      3   4     Based      12       A
# 4      4   5   Mukhles      56       C
# 5      5   6     kader      60       C
# 6      6   7     Abbas      45       A
# 7      7   8    Jabbar      50       B
# 8      8   9     Rafiq      78       B
# 9      9  10     Kasem       9       D
